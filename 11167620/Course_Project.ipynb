# %% [markdown]
# <div>
#     <b>Name:</b> Khristabel Aryeetey
# </div>
# <div>
#     <b>ID:</b> 11167620
# </div>
# <div>
#     <b>Class:</b> Materials Engineering
# </div>

# %%
# !pip install pandas matplotlib numpy
# !pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('red_wine.csv')

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# <h1>Feature Distribution</h1>
# The representation will give us how the dataset specifically the <b>alcohol</b> is distributed. From the dataset, we realize that the alcohol content has numerous unique values, and some values keep repeating. We can find that the values between <b><i>9.00<i/></b> and <b><i>10.00<i/></b> have the most occurrences in the dataset especially 9.50.

# %%
df['alcohol'].unique()
# Out:
# array([ 9.4       ,  9.8       , 10.        ,  9.5       , 10.5       ,
#         9.2       ,  9.9       ,  9.1       ,  9.3       ,  9.        ,
#         9.7       , 10.1       , 10.6       ,  9.6       , 10.8       ,
#        10.3       , 13.1       , 10.2       , 10.9       , 10.7       ,
#        12.9       , 10.4       , 13.        , 14.        , 11.5       ,
#        11.4       , 12.4       , 11.        , 12.2       , 12.8       ,
#        12.6       , 12.5       , 11.7       , 11.3       , 12.3       ,
#        12.        , 11.9       , 11.8       ,  8.7       , 13.3       ,
#        11.2       , 11.6       , 11.1       , 13.4       , 12.1       ,
#         8.4       , 12.7       , 14.9       , 13.2       , 13.6       ,
#        13.5       , 10.03333333,  9.55      ,  8.5       , 11.06666667,
#         9.56666667, 10.55      ,  8.8       , 13.56666667, 11.95      ,
#         9.95      ,  9.23333333,  9.25      ,  9.05      , 10.75      ])

# %%
plt.figure(figsize=(12, 7))
plt.hist(df['alcohol'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Alcohol Content in Red Wine')
plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <h1>Avalability of null</h1>
# The dataset has some cells that are empty

# %%
df.isnull().tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579          False             False        False           False      False
# 1580          False             False        False           False      False
# 1581          False             False        False           False      False
# 1582          False             False        False           False      False
# 1583          False             False        False           False      False
# 1584          False             False        False           False      False
# 1585          False             False        False           False      False
# 1586          False             False        False           False      False
# 1587          False             False        False           False      False
# 1588          False             False        False           False      False
# 1589          False             False        False           False      False
# ...

# %% [markdown]
# <h5>We can find some features which have empty data.
# Example fixed acidity, chlorides, free sulfur dioxide, density, and quality</h5>

# %%
df.isnull().sum()
# Out:
# fixed acidity           1
# volatile acidity        1
# citric acid             0
# residual sugar          0
# chlorides               4
# free sulfur dioxide     1
# total sulfur dioxide    0
# density                 1
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'fixed acidity', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'volatile acidity', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'citric acid', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'residual sugar', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'chlorides', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'total sulfur dioxide', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'density', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'pH', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = 'quality', y = 'alcohol', data = df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# ### We realize that the above statistics or graph plot gives us an estimate of how some parameters affect the quality of the wine. Simply put, some data parameters or features do not significantly impact the quality's outcome. Let's take the pH for example, no matter the level of the pH we can't tell whether the quality increases or decreases.
#
# ### But when we take the feature, Citric acid we can conclude that it has a great impact on the outcome being the quality because we can see as the value increases the quality decreases.
